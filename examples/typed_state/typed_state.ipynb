# %% [markdown]
# # Typed State Example
# A minimal example showing how to create the experimental StateGraph.

# %%
from olca.state_helpers import create_state_graph
sg = create_state_graph()
sg
